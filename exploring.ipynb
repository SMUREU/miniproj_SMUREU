# %%
import pandas as pd

# %%
df = pd.read_csv("data/gunownerdata.csv")

# %%
df
# Out:
#       FIP  Year    STATE    HFR  HFR_se  universl  permit  Fem_FS_S  \
# 0       1  1980  Alabama  0.608   0.031         0       0  0.824324
# 1       1  1981  Alabama  0.597   0.047         0       0  0.692308
# 2       1  1982  Alabama  0.661   0.036         0       0  0.771739
# 3       1  1983  Alabama  0.586   0.038         0       0  0.688172
# 4       1  1984  Alabama  0.624   0.036         0       0  0.710000
# ...   ...   ...      ...    ...     ...       ...     ...       ...
# 1845   56  2012  Wyoming  0.597   0.029         0       0  0.375000
# 1846   56  2013  Wyoming  0.613   0.032         0       0  0.529412
# 1847   56  2014  Wyoming  0.608   0.044         0       0  0.583333
# 1848   56  2015  Wyoming  0.549   0.032         0       0  0.393939
# 1849   56  2016  Wyoming  0.607   0.032         0       0  0.375000
#
#       Male_FS_S  BRFSS   GALLUP       GSS       PEW   HuntLic  GunsAmmo  \
# 0      0.833795   -9.0  0.55395  0.583632 -9.000000  0.291102 -0.509164
# ...

# %%
df = df[df['Year'] >= 2010]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 350 entries, 30 to 1849
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FIP        350 non-null    int64
#  1   Year       350 non-null    int64
#  2   STATE      350 non-null    str
#  3   HFR        350 non-null    float64
#  4   HFR_se     350 non-null    float64
#  5   universl   350 non-null    int64
#  6   permit     350 non-null    int64
#  7   Fem_FS_S   350 non-null    float64
#  8   Male_FS_S  350 non-null    float64
#  9   BRFSS      350 non-null    float64
#  10  GALLUP     350 non-null    float64
#  11  GSS        350 non-null    float64
#  12  PEW        350 non-null    float64
#  13  HuntLic    350 non-null    float64
#  14  GunsAmmo   350 non-null    float64
#  15  BackChk    350 non-null    float64
#  16  PewQChng   350 non-null    int64
#  17  BS1        350 non-null    float64
#  18  BS2        350 non-null    float64
# ...
